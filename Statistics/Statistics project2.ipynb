# %% [markdown]
# Загрузите данные, проверьте число наблюдений и столбцов, типы данных, наличие пропущенных значений, какие уникальные значения встречаются.
#
# Сколько уникальных рекламных кампаний было проведено?

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv(r'conversion.csv')

# %%
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# 0            7350       1    1.430000                 2                    1
# 1           17861       2    1.820000                 2                    0
# 2             693       0    0.000000                 1                    0
# 3            4259       1    1.250000                 1                    0
# 4            4133       1    1.290000                 1                    1
# ...           ...     ...         ...               ...                  ...
# 1138      1129773     252  358.189997                13                    2
# 1139       637549     120  173.880003                 3                    0
# 1140       151531      28   40.289999                 2                    0
# 1141       790253     135  198.710000                 8                    2
# 1142       513161     114  165.609999                 5                    2
#
# [1143 rows x 11 columns]

# %%
df.xyz_campaign_id.unique()
# Out:
# array([ 916,  936, 1178])

# %%
df.isna().sum()
# Out:
# ad_id                  0
# xyz_campaign_id        0
# fb_campaign_id         0
# age                    0
# gender                 0
# interest               0
# Impressions            0
# Clicks                 0
# Spent                  0
# Total_Conversion       0
# Approved_Conversion    0
# dtype: int64

# %%
df.dtypes
# Out:
# ad_id                    int64
# xyz_campaign_id          int64
# fb_campaign_id           int64
# age                     object
# gender                  object
# interest                 int64
# Impressions              int64
# Clicks                   int64
# Spent                  float64
# Total_Conversion         int64
# Approved_Conversion      int64
# dtype: object

# %%
df.xyz_campaign_id.nunique()
# Out:
# 3

# %% [markdown]
# Постройте график распределения числа показов (Impressions – сколько раз пользователи увидели данное объявление) для каждой рекламной кампании в Facebook, прологарифмировав значения.

# %%
df.sort_values(['Approved_Conversion'])
# Out:
#        ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 489   951420              936          123664  30-34      F        27
# 510   951853              936          123736  30-34      F        20
# 511   951854              936          123736  30-34      F        20
# 512   951856              936          123736  30-34      F        20
# 514   952001              936          123760  45-49      F        10
# ..       ...              ...             ...    ...    ...       ...
# 860  1121814             1178          144659  30-34      F        27
# 518  1121091             1178          144531  30-34      M        10
# 531  1121108             1178          144533  30-34      M        16
# 525  1121100             1178          144532  30-34      M        15
# 528  1121104             1178          144533  30-34      M        16
#
#      Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion
# 489          843       0    0.000000                 1                    0
# 510          529       0    0.000000                 0                    0
# 511          487       0    0.000000                 1                    0
# 512         4626       2    2.100000                 2                    0
# 514         5447       2    2.960000                 1                    0
# ..           ...     ...         ...               ...                  ...
# 860      2223278     421  612.300003                38                   13
# 518      1194718     141  254.049996                28                   14
# 531       984521      95  163.899997                26                   14
# 525      3052003     340  639.949998                60                   17
# 528      2080666     202  360.150002                40                   21
#
# [1143 rows x 11 columns]

# %%
df.groupby('fb_campaign_id', as_index = False).agg({'Impressions': 'sum'})
# Out:
#      fb_campaign_id  Impressions
# 0            103916         7350
# 1            103917        17861
# 2            103920          693
# 3            103928         8392
# 4            103929         1915
# ..              ...          ...
# 686          179977      1129773
# 687          179978       637549
# 688          179979       151531
# 689          179981       790253
# 690          179982       513161
#
# [691 rows x 2 columns]

# %%
sns.distplot(np.log(df.groupby('fb_campaign_id').agg({'Impressions': 'sum'})))
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Теперь посчитаем ещё несколько полезных метрик. Первая – CTR (click-through rate), которая показывает кликабельность, т.е. отношение числа кликов к количеству показов.
#
# CTR=clicks/impressions
#
# Создайте новую колонку, затем посмотрите на описательные статистики. В качестве ответа укажите ad_id объявления с наибольшим CTR.

# %%
df['CTR'] = df.Clicks / df.Impressions

# %%
df.sort_values(['CTR'])
# Out:
#       ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 434  950109              936          123445  30-34      M        20
# 467  951021              936          123597  30-34      F         7
# 516  952080              936          123774  40-44      F        27
# 181  747879              936          110947  30-34      F        30
# 182  747903              936          110951  30-34      F        63
# ..      ...              ...             ...    ...    ...       ...
# 448  950537              936          123516  40-44      M        36
# 476  951202              936          123627  45-49      F        26
# 505  951779              936          123723  45-49      F        27
# 440  950224              936          123464  40-44      M        20
# 150  738637              936          109857  45-49      F        24
#
#      Impressions  Clicks  Spent  Total_Conversion  Approved_Conversion  \
# 434          343       0   0.00                 1                    1
# 467          457       0   0.00                 1                    1
# 516          415       0   0.00                 1                    0
# 181          493       0   0.00                 1                    0
# 182         1491       0   0.00                 1                    1
# ..           ...     ...    ...               ...                  ...
# 448         1884       1   1.41                 1                    0
# 476         5307       3   4.29                 2                    1
# 505         3277       2   2.68                 1                    0
# 440         2367       2   2.84                 1                    1
# 150          944       1   1.42                 1                    0
#
#           CTR
# 434  0.000000
# 467  0.000000
# 516  0.000000
# 181  0.000000
# 182  0.000000
# ..        ...
# 448  0.000531
# 476  0.000565
# 505  0.000610
# 440  0.000845
# 150  0.001059
#
# [1143 rows x 12 columns]

# %% [markdown]
# Визуализируйте CTR с разбивкой по номеру рекламной кампании (xyz_campaign_id). Какому графику соответствует распределение CTR кампании 916?

# %%
sns.distplot(df.query('xyz_campaign_id == 916').CTR, kde = False, bins = 20)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# CPC (cost-per-click) – стоимость за клик пользователя по объявлению. Рассчитывается путём деления суммы потраченных денег на общее число кликов:
#
# CPC=spent/clicks
#
# Выведите описательные статистики для новой переменной, посмотрите на форму распределения. В ответе укажите межквартильный размах, округленный до двух знаков после точки.
#
# Обратите внимание, что в столбце могут встретиться NaN. Если вы используете функцию iqr из scipy, то следует указать аргумент nan_policy='omit', чтобы их проигнорировать. При построении графика необходимо использовать метод .dropna().

# %%
df['CPC'] = df.Spent / df.Clicks

# %%
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# 0            7350       1    1.430000                 2                    1
# 1           17861       2    1.820000                 2                    0
# 2             693       0    0.000000                 1                    0
# 3            4259       1    1.250000                 1                    0
# 4            4133       1    1.290000                 1                    1
# ...           ...     ...         ...               ...                  ...
# 1138      1129773     252  358.189997                13                    2
# 1139       637549     120  173.880003                 3                    0
# 1140       151531      28   40.289999                 2                    0
# 1141       790253     135  198.710000                 8                    2
# 1142       513161     114  165.609999                 5                    2
#
#            CTR       CPC
# 0     0.000136  1.430000
# 1     0.000112  0.910000
# 2     0.000000       NaN
# 3     0.000235  1.250000
# 4     0.000242  1.290000
# ...        ...       ...
# 1138  0.000223  1.421389
# 1139  0.000188  1.449000
# 1140  0.000185  1.438929
# 1141  0.000171  1.471926
# 1142  0.000222  1.452719
#
# [1143 rows x 13 columns]

# %%
df_1 = df.dropna()

# %%
df_1
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# 6      708889              916          103940  30-34      M        15
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# 0            7350       1    1.430000                 2                    1
# 1           17861       2    1.820000                 2                    0
# 3            4259       1    1.250000                 1                    0
# 4            4133       1    1.290000                 1                    1
# 6           15615       3    4.770000                 1                    0
# ...           ...     ...         ...               ...                  ...
# 1138      1129773     252  358.189997                13                    2
# 1139       637549     120  173.880003                 3                    0
# 1140       151531      28   40.289999                 2                    0
# 1141       790253     135  198.710000                 8                    2
# 1142       513161     114  165.609999                 5                    2
#
#            CTR       CPC
# 0     0.000136  1.430000
# 1     0.000112  0.910000
# 3     0.000235  1.250000
# 4     0.000242  1.290000
# 6     0.000192  1.590000
# ...        ...       ...
# 1138  0.000223  1.421389
# 1139  0.000188  1.449000
# 1140  0.000185  1.438929
# 1141  0.000171  1.471926
# 1142  0.000222  1.452719
#
# [936 rows x 13 columns]

# %%
sns.distplot(df_1.CPC, kde = False, bins = 20)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
stats.iqr(df.CPC, nan_policy='omit').round(2)
# Out:
# 0.25

# %% [markdown]
# Визуализируйте CPC с разбивкой по полу пользователей, которым были показаны объявления. Какой график получился?

# %%
plt.figure(figsize=(20, 12))
sns.distplot(df_1.query('gender == "M"').CPC, bins = 20)
sns.distplot(df_1.query('gender == "F"').CPC, bins = 20)
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Конверсия (conversion rate) – отношение числа пользователей, совершивших целевое действие на определенном этапе, к общему числу тех, кто дошел до данного этапа.
#
# Посчитайте конверсию из клика в покупку. В качестве ответа укажите конверсию для объявления 1121814 в процентах, округлив значение до 2 знаков после точки. Например, если значение кликов равно 10, а покупок – 2, то CR на данном этапе составляет 2/10=0.2=20.
#
# Note: клики – Clicks, покупки – Approved_Conversion.

# %%
df['CR'] = df.Approved_Conversion / df.Clicks

# %%
df
# Out:
#         ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0      708746              916          103916  30-34      M        15
# 1      708749              916          103917  30-34      M        16
# 2      708771              916          103920  30-34      M        20
# 3      708815              916          103928  30-34      M        28
# 4      708818              916          103928  30-34      M        28
# ...       ...              ...             ...    ...    ...       ...
# 1138  1314410             1178          179977  45-49      F       109
# 1139  1314411             1178          179978  45-49      F       110
# 1140  1314412             1178          179979  45-49      F       111
# 1141  1314414             1178          179981  45-49      F       113
# 1142  1314415             1178          179982  45-49      F       114
#
#       Impressions  Clicks       Spent  Total_Conversion  Approved_Conversion  \
# 0            7350       1    1.430000                 2                    1
# 1           17861       2    1.820000                 2                    0
# 2             693       0    0.000000                 1                    0
# 3            4259       1    1.250000                 1                    0
# 4            4133       1    1.290000                 1                    1
# ...           ...     ...         ...               ...                  ...
# 1138      1129773     252  358.189997                13                    2
# 1139       637549     120  173.880003                 3                    0
# 1140       151531      28   40.289999                 2                    0
# 1141       790253     135  198.710000                 8                    2
# 1142       513161     114  165.609999                 5                    2
#
#            CTR       CPC        CR
# 0     0.000136  1.430000  1.000000
# 1     0.000112  0.910000  0.000000
# 2     0.000000       NaN       NaN
# 3     0.000235  1.250000  0.000000
# 4     0.000242  1.290000  1.000000
# ...        ...       ...       ...
# 1138  0.000223  1.421389  0.007937
# 1139  0.000188  1.449000  0.000000
# 1140  0.000185  1.438929  0.000000
# 1141  0.000171  1.471926  0.014815
# 1142  0.000222  1.452719  0.017544
#
# [1143 rows x 14 columns]

# %%
(df.query('ad_id == 1121814').CR * 100).round(2)
# Out:
# 860    3.09
# Name: CR, dtype: float64
