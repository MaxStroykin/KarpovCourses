# %% [markdown]
# В рамках дополнительного проекта попробуем освоить API, позволяющий получать данные о музейных коллекциях. Это задание может пригодиться для большего понимания того, какими способами можно собирать и обрабатывать данные, например, для собственного проекта или другой рабочей задачи. Также вы можете более глубоко изучить документацию, чтобы потом исследовать другие интересные для себя вопросы по полученным данным :)
# Описание API
#
# Документация: https://metmuseum.github.io
#
# Ключ: для использования выбранного API (на момент написания задания) ключ не требуется :)
#
# Всего есть 4 основных раздела:
#
#     Объекты (Objects)
#     Объект (Object) – данные об объекте (например, о картине)
#     Департаменты (Departments) –  данные о департаменте/разделе (например, "Современное искусство")
#     Поиск (Search) – используется для поиска
#
# В рамках задач поработаем с блоками Object и Search.
#
# С более подробным описанием каждого доступного параметра можно ознакомиться в документации.
#
# Для начала, импортируйте нужные библиотеки:
#
# import requests
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# Сам запрос к API должен состоять из нескольких параметров. Пример обращения к поиску (Search):
#
# r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=QUERY')
# res = r.json()
#
# где QUERY – ключевое слово.
#
# Предположим, ваша задача – найти все произведения, связанные с подсолнухами. Выполните поиск по слову "sunflowers". Внимательно посмотрите на формат ответа и сохраните id полученных объектов в список sunflower_ids.
#
# В качестве ответа выберите id объектов (3), которые присутствуют в полученном списке
#
# Отлично! На предыдущем шаге мы получили результаты поиска. Следущий этап – собрать информацию об этих объектах.
#
# Пример текста запроса для получения информации об одном объекте (Object):
#
# r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/OBJECT_ID')
# obj_test = r_test.json()
#
# где OBJECT_ID – id объекта.
#
# Выполните запрос для объекта 437980. Для проверки соотнесите полученные параметры с их значениями
#
# Теперь напишите цикл, с помощью которого будет собрана информация об объектах, которые были получены на 2 шаге. Результаты запишите в датафрейм, а именно – следующие параметры:
#
#      objectID – id объекта
#     title – название
#     artistDisplayName – автор
#     department – департамент
#     objectBeginDate – дата (начало)
#     objectEndDate – дата (конец)
#     period – название периода
#     objectName – название/категория объекта
#     culture – культура
#
# Сколько объектов относятся к японской культуре? (culture –Japan)
#
# Теперь попробуем построить более сложный запрос с помощью секции "Search"! На этот раз параметры необходимо передать через "&", например, departmentId (id департамента – 1) и q (ключевое слово – cat):
#
# r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=1&q=cat')
# cats = r.json()
#
# Выполните поисковый запрос для департамента "Asian art" (departmentId = 6) с тегом "cat" и запишите id объектов в cat_ids. Используйте цикл из шага 4, чтобы получить данные о первой 1000 объектов из списка.
#
# Note: выполнение цикла может занять некоторое время (~5 минут), поэтому проверять его работоспособность лучше на более маленькой выборке!
#
# В качестве ответа укажите, в каком периоде (period) было выполнено наибольшее количество работ, представленных в музее?

# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=QUERY')
res = r.json()

# %%
res
# Out:
# {'total': 13,
#  'objectIDs': [778803,
#   839361,
#   208967,
#   436180,
#   435821,
#   437449,
#   60451,
#   839021,
#   857478,
#   503341,
#   436105,
#   436883,
#   436283]}

# %%
url = 'https://collectionapi.metmuseum.org/public/collection/v1/search?q='
IDs = 'sunflowers'
r = requests.get(url+IDs)
res = r.json()

# %%
sunflower_ids = res['objectIDs']

# %%
sunflower_ids
# Out:
# [436524,
#  484935,
#  437112,
#  210191,
#  431264,
#  397949,
#  656530,
#  480725,
#  486590,
#  485308,
#  375281,
#  705155,
#  11922,
#  816522,
#  2032,
#  343052,
#  20141,
#  2019,
#  208554,
#  403496,
#  360837,
#  437115,
#  207869,
#  761604,
#  400581,
#  423400,
#  707887,
#  223828,
#  682927,
#  57922,
#  649813,
#  79739,
#  193938,
#  339347,
#  208218,
#  437984,
#  202228,
#  436534,
#  704667,
#  696949,
#  437329,
#  436252,
#  437526,
#  436580,
#  363282,
#  190739,
#  207753,
#  347980,
#  822570,
#  487043,
#  203893,
#  367434,
#  423237,
#  262423,
#  839296,
#  367817,
#  13644,
#  18362,
#  820022,
#  648617,
#  761731,
#  814626,
#  207967,
#  626832,
#  262430,
#  262428,
#  707697,
#  205386,
#  262378,
#  426804,
#  664519,
#  633526,
#  436121,
#  369073,
#  747779,
#  436144,
#  852414,
#  427872,
#  436530,
#  436535,
#  436529,
#  437980,
#  724844,
#  834585,
#  834580,
#  834765]

# %%
numbers = [437329, 436524, 20149, 16822570, 2032]

# %%
r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/210191')
obj_test = r_test.json()

# %%
obj_test
# Out:
# {'objectID': 210191,
#  'isHighlight': False,
#  'accessionNumber': '2000.126',
#  'accessionYear': '2000',
#  'isPublicDomain': False,
#  'primaryImage': '',
#  'primaryImageSmall': '',
#  'additionalImages': [],
#  'constituents': [{'constituentID': 38872,
#    'role': 'Manufacturer',
#    'name': 'Rozenburg Plateelfabriek',
#    'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500054784',
#    'constituentWikidata_URL': '',
#    'gender': ''}],
#  'department': 'European Sculpture and Decorative Arts',
#  'objectName': 'Vase',
#  'title': 'Vase with sunflowers',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': 'Manufacturer',
#  'artistPrefix': '',
#  'artistDisplayName': 'Rozenburg Plateelfabriek',
#  'artistDisplayBio': '1883–1917',
#  'artistSuffix': '',
#  'artistAlphaSort': 'Rozenburg Plateelfabriek',
#  'artistNationality': 'Dutch',
#  'artistBeginDate': '1883',
#  'artistEndDate': '1917',
#  'artistGender': '',
#  'artistWikidata_URL': '',
#  'artistULAN_URL': 'http://vocab.getty.edu/page/ulan/500054784',
#  'objectDate': '1896',
#  'objectBeginDate': 1896,
#  'objectEndDate': 1896,
#  'medium': 'Glazed earthenware',
#  'dimensions': 'Height: 15 3/8 in. (39.1 cm)',
#  'measurements': [{'elementName': 'Height',
#    'elementDescription': None,
#    'elementMeasurements': {'Height': 39.052578}}],
#  'creditLine': 'Purchase, Gifts of Mrs. Russell Sage and The Hearst Foundation, by exchange and Rogers Fund, 2000',
#  'geographyType': '',
#  'city': '',
#  'state': '',
#  'county': '',
#  'country': '',
#  'region': '',
#  'subregion': '',
#  'locale': '',
#  'locus': '',
#  'excavation': '',
#  'river': '',
#  'classification': 'Ceramics-Pottery',
#  'rightsAndReproduction': '',
#  'linkResource': '',
#  'metadataDate': '2020-09-16T18:35:19.457Z',
#  'repository': 'Metropolitan Museum of Art, New York, NY',
#  'objectURL': 'https://www.metmuseum.org/art/collection/search/210191',
#  'tags': [{'term': 'Sunflowers',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300404749',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q171497'}],
#  'objectWikidata_URL': '',
#  'isTimelineWork': False,
#  'GalleryNumber': '556'}

# %%
sunflower_ids
# Out:
# [436524,
#  484935,
#  437112,
#  210191,
#  431264,
#  397949,
#  656530,
#  480725,
#  486590,
#  485308,
#  375281,
#  705155,
#  11922,
#  816522,
#  2032,
#  343052,
#  20141,
#  2019,
#  208554,
#  403496,
#  360837,
#  437115,
#  207869,
#  761604,
#  400581,
#  423400,
#  707887,
#  223828,
#  682927,
#  57922,
#  649813,
#  79739,
#  193938,
#  339347,
#  208218,
#  437984,
#  202228,
#  436534,
#  704667,
#  696949,
#  437329,
#  436252,
#  437526,
#  436580,
#  363282,
#  190739,
#  207753,
#  347980,
#  822570,
#  487043,
#  203893,
#  367434,
#  423237,
#  262423,
#  839296,
#  367817,
#  13644,
#  18362,
#  820022,
#  648617,
#  761731,
#  814626,
#  207967,
#  626832,
#  262430,
#  262428,
#  707697,
#  205386,
#  262378,
#  426804,
#  664519,
#  633526,
#  436121,
#  369073,
#  747779,
#  436144,
#  852414,
#  427872,
#  436530,
#  436535,
#  436529,
#  437980,
#  724844,
#  834585,
#  834580,
#  834765]

# %%
df = []

# %%
df
# Out:
# []

# %%
for i in sunflower_ids:
    try:
        r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{i}')
        obj_test = r_test.json()
        df.append([obj_test['objectID'], obj_test['title'], obj_test['artistDisplayName'], obj_test['department'], obj_test['objectBeginDate'], obj_test['objectEndDate'], obj_test['period'], obj_test['objectName'], obj_test['culture']])
    except:
        continue

# %%
df
# Out:
# [[436524,
#   'Sunflowers',
#   'Vincent van Gogh',
#   'European Paintings',
#   1887,
#   1887,
#   '',
#   'Painting',
#   ''],
#  [484935,
#   'Sunflowers',
#   'Edward McKnight Kauffer',
#   'Modern and Contemporary Art',
#   1921,
#   1921,
#   '',
#   'Painting',
#   ''],
#  [437112,
#   'Bouquet of Sunflowers',
#   'Claude Monet',
#   'European Paintings',
#   1881,
#   1881,
#   '',
#   'Painting',
#   ''],
#  [210191,
#   'Vase with sunflowers',
#   'Rozenburg Plateelfabriek',
#   'European Sculpture and Decorative Arts',
#   1896,
#   1896,
#   '',
#   'Vase',
#   ''],
#  [431264,
#   'Sunflowers',
#   'Lily Converse',
#   'Drawings and Prints',
#   1941,
#   1941,
#   '',
#   'Print',
#   ''],
#  [397949,
#   'Sunflowers',
#   'Angela Straeter',
#   'Drawings and Prints',
#   1935,
#   1943,
#   '',
#   'Print',
#   ''],
#  [656530,
#   'Sunflowers',
#   'Howard Cook',
#   'Drawings and Prints',
#   1930,
#   1930,
#   '',
#   'Print',
#   ''],
#  [480725,
#   'Large Sunflowers',
#   'Emil Nolde',
#   'Modern and Contemporary Art',
#   1928,
#   1928,
#   '',
#   'Painting',
#   ''],
#  [486590,
#   'Moroccan Sunflowers',
#   'Charles Baskerville',
#   'Modern and Contemporary Art',
#   1940,
#   1940,
#   '',
#   'Painting',
#   ''],
#  [485308,
#   'Sunflower',
#   'Joan Mitchell',
#   'Modern and Contemporary Art',
#   1969,
#   1969,
#   '',
#   'Painting',
#   ''],
#  [375281,
#   'Walk Among Sunflowers',
#   'Louis Lozowick',
#   'Drawings and Prints',
#   1957,
#   1957,
#   '',
#   'Print',
#   ''],
#  [705155,
#   'Fan Design with Cats and Sunflowers',
#   'Henri-Charles Guérard',
#   'Drawings and Prints',
#   1880,
#   1895,
#   '',
#   'Drawing',
#   ''],
#  [11922,
#   'Clytie',
#   'William Henry Rinehart',
#   'The American Wing',
#   1869,
#   1872,
#   '',
#   'Sculpture',
#   'American'],
#  [816522,
#   'Flowers in a Grotesque Vase',
#   'Orsola Maddalena Caccia',
#   'European Paintings',
#   1630,
#   1640,
#   '',
#   'Painting',
#   ''],
#  [2032,
#   'Chest with drawer',
#   '',
#   'The American Wing',
#   1705,
#   1705,
#   '',
#   'Chest with drawer',
#   'American'],
#  [343052,
#   'Design for a Wall Decoration with Peacock, Cranes, and Sunflowers for the Restaurant in Hotel Langham (Paris)',
#   'Emile Hurtré',
#   'Drawings and Prints',
#   1896,
#   1898,
#   '',
#   'Drawing Ornament & Architecture',
#   ''],
#  [20141,
#   'Plaque',
#   'Chelsea Keramic Art Works',
#   'The American Wing',
#   1875,
#   1885,
#   '',
#   'Plaque',
#   'American'],
#  [2019,
#   'Chest with drawers',
#   'Peter Blin',
#   'The American Wing',
#   1675,
#   1700,
#   '',
#   'Chest with drawers',
#   'American'],
#  [208554,
#   'Charger',
#   'F. Gadesden',
#   'European Sculpture and Decorative Arts',
#   1876,
#   1876,
#   '',
#   'Charger',
#   ''],
#  [403496,
#   'Boy with Sunflowers',
#   'Walter Williams',
#   'Drawings and Prints',
#   1965,
#   1965,
#   '',
#   'Print',
#   ''],
#  [360837,
#   'Sir Anthony Van Dyck with a Sunflower',
#   'Wenceslaus Hollar',
#   'Drawings and Prints',
#   1644,
#   1644,
#   '',
#   'Print',
#   ''],
#  [437115,
#   'Chrysanthemums',
#   'Claude Monet',
#   'European Paintings',
#   1882,
#   1882,
#   '',
#   'Painting',
#   ''],
#  [207869,
#   'Louis XVI',
#   'Philippe Laurent Roland',
#   'European Sculpture and Decorative Arts',
#   1787,
#   1787,
#   '',
#   'Portrait roundel',
#   ''],
#  [761604,
#   '',
#   'Unrecorded  Edgefield District potter',
#   'The American Wing',
#   1850,
#   1880,
#   '',
#   'Face Vessel',
#   'American'],
#  [400581,
#   'Sunflower (Helianthus annuus), from the Flowers series for Old Judge Cigarettes',
#   'Goodwin & Company',
#   'Drawings and Prints',
#   1890,
#   1890,
#   '',
#   'Print',
#   ''],
#  [423400,
#   'Sunflower: Haughtiness, from the series Floral Beauties and Language of Flowers (N75) for Duke brand cigarettes',
#   'American Tobacco Company',
#   'Drawings and Prints',
#   1892,
#   1892,
#   '',
#   'Print',
#   ''],
#  [707887,
#   'Botanical dish with white sunflower',
#   'Chelsea Porcelain Manufactory',
#   'European Sculpture and Decorative Arts',
#   1750,
#   1760,
#   '',
#   'Dish',
#   ''],
#  [223828,
#   'Piece',
#   '',
#   'European Sculpture and Decorative Arts',
#   1885,
#   1899,
#   '',
#   'Piece',
#   ''],
#  [682927,
#   '42. Black-Eyedsusan, bakery insert card from the Flower Pictures series (D36), issued by the Freihofer Baking Company',
#   'Freihofer Baking Company',
#   'Drawings and Prints',
#   1920,
#   1929,
#   '',
#   'Print',
#   ''],
#  [57922,
#   'Incense box',
#   '',
#   'Asian Art',
#   1700,
#   1799,
#   'Edo period (1615–1868)',
#   'Incense box',
#   'Japan'],
#  [649813,
#   "New Year's Card",
#   'Mela Koehler',
#   'Drawings and Prints',
#   1911,
#   1911,
#   '',
#   'Print',
#   ''],
#  [79739,
#   'Shorts',
#   'Paul Smith',
#   'Costume Institute',
#   1989,
#   1990,
#   '',
#   'Shorts',
#   'British'],
#  [193938,
#   'Souvenir',
#   'Pierre-Denis Chaumont',
#   'European Sculpture and Decorative Arts',
#   1789,
#   1792,
#   '',
#   'Souvenir',
#   ''],
#  [339347,
#   'April, May, June',
#   'Louis John Rhead',
#   'Drawings and Prints',
#   1896,
#   1896,
#   '',
#   'Print; Poster',
#   ''],
#  [208218,
#   'Dish',
#   '',
#   'European Sculpture and Decorative Arts',
#   1685,
#   1699,
#   '',
#   'Dish',
#   ''],
#  [437984,
#   'La Berceuse (Woman Rocking a Cradle; Augustine-Alix Pellicot Roulin, 1851–1930)',
#   'Vincent van Gogh',
#   'European Paintings',
#   1889,
#   1889,
#   '',
#   'Painting',
#   ''],
#  [202228,
#   'Carpet with Fame and Fortitude',
#   'Savonnerie Manufactory',
#   'European Sculpture and Decorative Arts',
#   1668,
#   1685,
#   '',
#   'Carpet',
#   ''],
#  [436534,
#   'Roses',
#   'Vincent van Gogh',
#   'European Paintings',
#   1890,
#   1890,
#   '',
#   'Painting',
#   ''],
#  [437329,
#   'The Abduction of the Sabine Women',
#   'Nicolas Poussin',
#   'European Paintings',
#   1633,
#   1634,
#   '',
#   'Painting',
#   ''],
#  [436252,
#   'James Stuart (1612–1655), Duke of Richmond and Lennox',
#   'Anthony van Dyck',
#   'European Paintings',
#   1633,
#   1635,
#   '',
#   'Painting',
#   ''],
#  [437526,
#   'A Forest at Dawn with a Deer Hunt',
#   'Peter Paul Rubens',
#   'European Paintings',
#   1630,
#   1640,
#   '',
#   'Painting',
#   ''],
#  [436580,
#   'Aegina Visited by Jupiter',
#   'Jean-Baptiste Greuze',
#   'European Paintings',
#   1767,
#   1769,
#   '',
#   'Painting',
#   ''],
#  [363282,
#   'Fireplace and Grate Design with Sunflower Andirons',
#   'Anonymous, British, 19th century',
#   'Drawings and Prints',
#   1800,
#   1900,
#   '',
#   'Drawing ; Ornament and architecture',
#   ''],
#  [190739,
#   'Clytie',
#   'George Frederic Watts',
#   'European Sculpture and Decorative Arts',
#   1863,
#   1875,
#   '',
#   'Bust',
#   ''],
#  [207753,
#   'Pair of double doors',
#   '',
#   'European Sculpture and Decorative Arts',
#   1705,
#   1715,
#   '',
#   'Double doors',
#   ''],
#  [347980,
#   'Songs of Innocence and of Experience: My Pretty Rose Tree, Ah! Sun-Flower, The Lily',
#   'William Blake',
#   'Drawings and Prints',
#   1820,
#   1830,
#   '',
#   'Print',
#   ''],
#  [822570,
#   'Wilde on Us. Something To "Live Up" To in America (published in "Harper\'s Bazar," June 10, 1882)',
#   'Thomas Nast',
#   'Drawings and Prints',
#   1882,
#   1882,
#   '',
#   'Print',
#   ''],
#  [487043,
#   'Untitled',
#   'Anselm Kiefer',
#   'Modern and Contemporary Art',
#   1996,
#   1996,
#   '',
#   'Drawing',
#   ''],
#  [203893,
#   'Mirror',
#   'Johannes Hannart (or Jan Hanat)',
#   'European Sculpture and Decorative Arts',
#   1680,
#   1705,
#   '',
#   'Mirror',
#   ''],
#  [367434,
#   'Raped (Vergewaltigt)',
#   'Käthe Kollwitz',
#   'Drawings and Prints',
#   1921,
#   1921,
#   '',
#   'Print',
#   ''],
#  [423237,
#   'Helen Standish as "The Sunflower," from the series Fancy Dress Ball Costumes (N73) for Duke brand cigarettes',
#   'W. Duke, Sons & Co.',
#   'Drawings and Prints',
#   1889,
#   1889,
#   '',
#   'Print',
#   ''],
#  [262423,
#   'Giverny',
#   'Stephen Shore',
#   'Photographs',
#   1977,
#   1977,
#   '',
#   'Photograph',
#   ''],
#  [367817,
#   'Sunflower Wallpaper Border',
#   'Clement J. Heaton',
#   'Drawings and Prints',
#   1893,
#   1906,
#   '',
#   'Wallpaper',
#   ''],
#  [13644,
#   'Coverlet',
#   '',
#   'The American Wing',
#   1836,
#   1836,
#   '',
#   'Coverlet',
#   'American'],
#  [18362,
#   'Quilt, Baskets pattern',
#   '',
#   'The American Wing',
#   1927,
#   1933,
#   '',
#   'Quilt',
#   'American'],
#  [820022,
#   '"Mr. O\'Wilde, You are not the first one that has grasped at a Shadow" (published in "Harper\'s Bazar," February 11, 1882)',
#   'Thomas Nast',
#   'Drawings and Prints',
#   1882,
#   1882,
#   '',
#   'Print',
#   ''],
#  [648617,
#   '2e Suite de différens Attributs, Trophées et Groupes de Fleurs, Plate 6',
#   'Pierre Ranson',
#   'Drawings and Prints',
#   1773,
#   1783,
#   '',
#   'Print Ornament & Architecture',
#   ''],
#  [761731,
#   '"An Aesthetic Darkey" from the "Aiken and Vicinity" series',
#   'James A. Palmer',
#   'The American Wing',
#   1882,
#   1882,
#   '',
#   'Photograph',
#   'American'],
#  [814626,
#   '"The Wilde Woman of Aiken," from the "Aiken and Vicinity" series',
#   'James A. Palmer',
#   'The American Wing',
#   1882,
#   1882,
#   '',
#   'Photograph',
#   'American'],
#  [207967,
#   'Plate with "Bamboo and Fan" pattern',
#   'Minton(s)',
#   'European Sculpture and Decorative Arts',
#   1872,
#   1882,
#   '',
#   'Plate',
#   ''],
#  [626832,
#   'Sunflower Effigies',
#   '',
#   'The Michael C. Rockefeller Wing',
#   1200,
#   1450,
#   '',
#   'Ornaments',
#   'Ancestral Pueblo'],
#  [262430,
#   'Giverny',
#   'Stephen Shore',
#   'Photographs',
#   1977,
#   1977,
#   '',
#   'Photograph',
#   ''],
#  [262428,
#   'Giverny',
#   'Stephen Shore',
#   'Photographs',
#   1977,
#   1977,
#   '',
#   'Photograph',
#   ''],
#  [707697,
#   'Cobweb Valentine',
#   'Anonymous',
#   'Drawings and Prints',
#   1825,
#   1840,
#   '',
#   'Valentine',
#   ''],
#  [205386,
#   'Tea and coffee set (teapot, coffeepot, milk jug, sugar bowl)',
#   '',
#   'European Sculpture and Decorative Arts',
#   1800,
#   1815,
#   '',
#   'Tea and coffee set',
#   ''],
#  [262378,
#   'Giverny',
#   'Stephen Shore',
#   'Photographs',
#   1977,
#   1977,
#   '',
#   'Photograph',
#   ''],
#  [426804,
#   'Helen Standish as "The Sunflower," from the series Fancy Dress Ball Costumes (N73) for Duke\'s Mixture Smoking Tobacco',
#   'W. Duke, Sons & Co.',
#   'Drawings and Prints',
#   1889,
#   1889,
#   '',
#   'Print',
#   ''],
#  [664519,
#   'Sunflower (Dwarf)–Adoration, from the Language of Flowers series (N366) issued by the Lone Jack Cigarette Company to promote Ruby Cigarettes',
#   'Lone Jack Cigarette Company',
#   'Drawings and Prints',
#   1888,
#   1888,
#   '',
#   'Print',
#   ''],
#  [633526,
#   "Woman in purple bodice with sunflowers, from the Costumes and Flowers series (N304) to promote Mayo's Cut Plug Tobacco",
#   'P.H. Mayo & Brother, Richmond, Virginia',
#   'Drawings and Prints',
#   1890,
#   1899,
#   '',
#   'Print',
#   ''],
#  [436121,
#   'A Woman Seated beside a Vase of Flowers (Madame Paul Valpinçon?)',
#   'Edgar Degas',
#   'European Paintings',
#   1865,
#   1865,
#   '',
#   'Painting',
#   ''],
#  [369073,
#   'Rest on the Flight into Egypt',
#   'Anthony van Dyck',
#   'Drawings and Prints',
#   1650,
#   1659,
#   '',
#   'Print',
#   ''],
#  [747779,
#   'Suggestions, Pl. 8',
#   'Emile-Allain Séguy',
#   'Drawings and Prints',
#   1923,
#   1923,
#   '',
#   'Book Print Ornament & Architecture',
#   ''],
#  [436144,
#   'James-Jacques-Joseph Tissot (1836–1902)',
#   'Edgar Degas',
#   'European Paintings',
#   1867,
#   1868,
#   '',
#   'Painting',
#   ''],
#  [852414,
#   'Chairman C. A. Dana Buttonholes U.S. (published in "Time," September 7, 1889)',
#   'Thomas Nast',
#   'Drawings and Prints',
#   1889,
#   1889,
#   '',
#   'Print',
#   ''],
#  [427872,
#   'Helen Standish as "The Sunflower," from the Fancy Dress Ball Costumes series (N107) to promote Honest Long Cut Tobacco manufactured by W. Duke Sons & Co.',
#   'W. Duke, Sons & Co.',
#   'Drawings and Prints',
#   1889,
#   1889,
#   '',
#   'Print',
#   ''],
#  [436530,
#   'Oleanders',
#   'Vincent van Gogh',
#   'European Paintings',
#   1888,
#   1888,
#   '',
#   'Painting',
#   ''],
#  [436535,
#   'Wheat Field with Cypresses',
#   'Vincent van Gogh',
#   'European Paintings',
#   1889,
#   1889,
#   '',
#   'Painting',
#   ''],
#  [436529,
#   "L'Arlésienne: Madame Joseph-Michel Ginoux (Marie Julien, 1848–1911)",
#   'Vincent van Gogh',
#   'European Paintings',
#   1888,
#   1889,
#   '',
#   'Painting',
#   ''],
#  [437980,
#   'Cypresses',
#   'Vincent van Gogh',
#   'European Paintings',
#   1889,
#   1889,
#   '',
#   'Painting',
#   ''],
#  [724844,
#   'Design for Embroidery with Two Large Garlands and a Variety of Labelled Stylized Flowers',
#   'Italian School',
#   'Drawings and Prints',
#   1845,
#   1905,
#   '',
#   'Drawing Ornament & Architecture',
#   ''],
#  [834585,
#   'A Life in a Year–The Garden–Noon, from "Picture Poesies"',
#   'Arthur Boyd Houghton',
#   'Drawings and Prints',
#   1866,
#   1874,
#   '',
#   'Print',
#   ''],
#  [834580,
#   'A Life in a Year–The Garden–Noon, from "Picture Poesies"',
#   'Arthur Boyd Houghton',
#   'Drawings and Prints',
#   1866,
#   1874,
#   '',
#   'Print',
#   ''],
#  [834765,
#   'A Child\'s Garden, from "Picture Poesies"',
#   'Arthur Boyd Houghton',
#   'Drawings and Prints',
#   1865,
#   1874,
#   '',
#   'Print',
#   '']]

# %%
df_1 = pd.DataFrame(df)

# %%
df_1
# Out:
#          0                                                  1  \
# 0   436524                                         Sunflowers
# 1   484935                                         Sunflowers
# 2   437112                              Bouquet of Sunflowers
# 3   210191                               Vase with sunflowers
# 4   431264                                         Sunflowers
# ..     ...                                                ...
# 78  437980                                          Cypresses
# 79  724844  Design for Embroidery with Two Large Garlands ...
# 80  834585  A Life in a Year–The Garden–Noon, from "Pictur...
# 81  834580  A Life in a Year–The Garden–Noon, from "Pictur...
# 82  834765           A Child's Garden, from "Picture Poesies"
#
#                            2                                       3     4  \
# 0           Vincent van Gogh                      European Paintings  1887
# 1    Edward McKnight Kauffer             Modern and Contemporary Art  1921
# 2               Claude Monet                      European Paintings  1881
# 3   Rozenburg Plateelfabriek  European Sculpture and Decorative Arts  1896
# 4              Lily Converse                     Drawings and Prints  1941
# ..                       ...                                     ...   ...
# 78          Vincent van Gogh                      European Paintings  1889
# 79            Italian School                     Drawings and Prints  1845
# 80      Arthur Boyd Houghton                     Drawings and Prints  1866
# 81      Arthur Boyd Houghton                     Drawings and Prints  1866
# 82      Arthur Boyd Houghton                     Drawings and Prints  1865
#
#        5 6                                 7 8
# 0   1887                            Painting
# 1   1921                            Painting
# 2   1881                            Painting
# 3   1896                                Vase
# 4   1941                               Print
# ..   ... ..                              ... ..
# 78  1889                            Painting
# 79  1905     Drawing Ornament & Architecture
# 80  1874                               Print
# 81  1874                               Print
# 82  1874                               Print
#
# [83 rows x 9 columns]

# %%
df_2 = df_1.rename(columns = {0: 'objectID', 1: 'title', 2: 'artistDisplayName', 3: 'department', 4: 'objectBeginDate', 5: 'objectEndDate', 6: 'period', 7: 'objectName', 8: 'culture'})

# %%
df_2.query('culture == "Japan"')
# Out:
#     objectID        title artistDisplayName department  objectBeginDate  \
# 29     57922  Incense box                    Asian Art             1700
#
#     objectEndDate                  period   objectName culture
# 29           1799  Edo period (1615–1868)  Incense box   Japan

# %%
sunflower_ids
# Out:
# [436524,
#  484935,
#  437112,
#  210191,
#  431264,
#  397949,
#  656530,
#  480725,
#  486590,
#  485308,
#  375281,
#  705155,
#  11922,
#  816522,
#  2032,
#  343052,
#  20141,
#  2019,
#  208554,
#  403496,
#  360837,
#  437115,
#  207869,
#  761604,
#  400581,
#  423400,
#  707887,
#  223828,
#  682927,
#  57922,
#  649813,
#  79739,
#  193938,
#  339347,
#  208218,
#  437984,
#  202228,
#  436534,
#  704667,
#  696949,
#  437329,
#  436252,
#  437526,
#  436580,
#  363282,
#  190739,
#  207753,
#  347980,
#  822570,
#  487043,
#  203893,
#  367434,
#  423237,
#  262423,
#  839296,
#  367817,
#  13644,
#  18362,
#  820022,
#  648617,
#  761731,
#  814626,
#  207967,
#  626832,
#  262430,
#  262428,
#  707697,
#  205386,
#  262378,
#  426804,
#  664519,
#  633526,
#  436121,
#  369073,
#  747779,
#  436144,
#  852414,
#  427872,
#  436530,
#  436535,
#  436529,
#  437980,
#  724844,
#  834585,
#  834580,
#  834765]

# %%
df_5 = []

# %%
for i in sunflower_ids:
    try:
        r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{i}')
        obj_test = r_test.json()
        df_5.append(obj_test['culture'])
    except:
        continue

# %%
df_5
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'American',
#  '',
#  'American',
#  '',
#  'American',
#  'American',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'American',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Japan',
#  '',
#  'British',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'American',
#  'American',
#  '',
#  '',
#  'American',
#  'American',
#  '',
#  'Ancestral Pueblo',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
cats = r.json()

# %%
cats
# Out:
# {'total': 2964,
#  'objectIDs': [49698,
#   49470,
#   53222,
#   36221,
#   60873,
#   70541,
#   752008,
#   43402,
#   47358,
#   49467,
#   54747,
#   54626,
#   55919,
#   59775,
#   55923,
#   36075,
#   50826,
#   57204,
#   53653,
#   42922,
#   56602,
#   47051,
#   47052,
#   72842,
#   69780,
#   59121,
#   38952,
#   39199,
#   38177,
#   59903,
#   73809,
#   59763,
#   49050,
#   58462,
#   45282,
#   39092,
#   38158,
#   38160,
#   38162,
#   38994,
#   50780,
#   53441,
#   55948,
#   54124,
#   59248,
#   36411,
#   58779,
#   73046,
#   38949,
#   671015,
#   42932,
#   45065,
#   56780,
#   42915,
#   59249,
#   36346,
#   51660,
#   670898,
#   55914,
#   39764,
#   55967,
#   69410,
#   68841,
#   55148,
#   76442,
#   37011,
#   36621,
#   58218,
#   54445,
#   57560,
#   56070,
#   41681,
#   53590,
#   58002,
#   45667,
#   50827,
#   46723,
#   36539,
#   38452,
#   39698,
#   39699,
#   54809,
#   57106,
#   75200,
#   38951,
#   38176,
#   38462,
#   75909,
#   38293,
#   38315,
#   52995,
#   52994,
#   53005,
#   53422,
#   70582,
#   73158,
#   671014,
#   670965,
#   75747,
#   671023,
#   74813,
#   53408,
#   53203,
#   53007,
#   53200,
#   53457,
#   53231,
#   53416,
#   53414,
#   53001,
#   53234,
#   52996,
#   53006,
#   53410,
#   53176,
#   53002,
#   671016,
#   670994,
#   53419,
#   761386,
#   53221,
#   53439,
#   671056,
#   53456,
#   53010,
#   53219,
#   54540,
#   53446,
#   53241,
#   53187,
#   53167,
#   53179,
#   72585,
#   671024,
#   53178,
#   50486,
#   670961,
#   55802,
#   53427,
#   43247,
#   74421,
#   53429,
#   53165,
#   53175,
#   53190,
#   53157,
#   53172,
#   670891,
#   39901,
#   670920,
#   53449,
#   670943,
#   56128,
#   78227,
#   667348,
#   45640,
#   54576,
#   54567,
#   670908,
#   53660,
#   670916,
#   670910,
#   670949,
#   670883,
#   73352,
#   671036,
#   670989,
#   671042,
#   670894,
#   670947,
#   670882,
#   670938,
#   671039,
#   53458,
#   670917,
#   68411,
#   74423,
#   36118,
#   38451,
#   53444,
#   53426,
#   64872,
#   670974,
#   45358,
#   670968,
#   671035,
#   54184,
#   76091,
#   69670,
#   77871,
#   76458,
#   39902,
#   72747,
#   45359,
#   39163,
#   53230,
#   53453,
#   670897,
#   670995,
#   73355,
#   73358,
#   670921,
#   671007,
#   671005,
#   670993,
#   53424,
#   36315,
#   53228,
#   670981,
#   53454,
#   77657,
#   74424,
#   69860,
#   53465,
#   76769,
#   75586,
#   44292,
#   37397,
#   38267,
#   38165,
#   670950,
#   670942,
#   670928,
#   671026,
#   670979,
#   671046,
#   54774,
#   671055,
#   671050,
#   53443,
#   53466,
#   56901,
#   671008,
#   78670,
#   671028,
#   53409,
#   671027,
#   670915,
#   53401,
#   53245,
#   38926,
#   53202,
#   52987,
#   53421,
#   53246,
#   53445,
#   53423,
#   65392,
#   53405,
#   53008,
#   670913,
#   53183,
#   671031,
#   38304,
#   78195,
#   73359,
#   39076,
#   44723,
#   78197,
#   76453,
#   40765,
#   53174,
#   671020,
#   53238,
#   40478,
#   77799,
#   670951,
#   76462,
#   670963,
#   57062,
#   62744,
#   52988,
#   53406,
#   53404,
#   670923,
#   53004,
#   53207,
#   53199,
#   670541,
#   670542,
#   670540,
#   53455,
#   40285,
#   65394,
#   39331,
#   53189,
#   670887,
#   670904,
#   37800,
#   38265,
#   670933,
#   49129,
#   670896,
#   670907,
#   61658,
#   42725,
#   39640,
#   38945,
#   72381,
#   671032,
#   670903,
#   670960,
#   53892,
#   53195,
#   65417,
#   670889,
#   54779,
#   53181,
#   727181,
#   52990,
#   671052,
#   52946,
#   41493,
#   53461,
#   53451,
#   57612,
#   38303,
#   39635,
#   42722,
#   38011,
#   38930,
#   38159,
#   38341,
#   38335,
#   38330,
#   53430,
#   53447,
#   53448,
#   60473,
#   53154,
#   53156,
#   53237,
#   53226,
#   40507,
#   42693,
#   40256,
#   52378,
#   48754,
#   50345,
#   46509,
#   42219,
#   53120,
#   38435,
#   38620,
#   39413,
#   39639,
#   39111,
#   40527,
#   40528,
#   74906,
#   38202,
#   53123,
#   671001,
#   49238,
#   40510,
#   644664,
#   53223,
#   54773,
#   45657,
#   671017,
#   670945,
#   671034,
#   53242,
#   53162,
#   54782,
#   53163,
#   53194,
#   53463,
#   53186,
#   43091,
#   53240,
#   40257,
#   42733,
#   53450,
#   42348,
#   42162,
#   700508,
#   45812,
#   48879,
#   40524,
#   53415,
#   53462,
#   36100,
#   53212,
#   53188,
#   53413,
#   49174,
#   75831,
#   44616,
#   42704,
#   39859,
#   38983,
#   39623,
#   42015,
#   42088,
#   72605,
#   73309,
#   40361,
#   40467,
#   40468,
#   42585,
#   854924,
#   40741,
#   40604,
#   40605,
#   40612,
#   40611,
#   40610,
#   40606,
#   40607,
#   40674,
#   40608,
#   40613,
#   40614,
#   40609,
#   40603,
#   36451,
#   38228,
#   74448,
#   39166,
#   38328,
#   856419,
#   670970,
#   45763,
#   39482,
#   53460,
#   53158,
#   52096,
#   78198,
#   39524,
#   49216,
#   50898,
#   76733,
#   39527,
#   42463,
#   39528,
#   42378,
#   38108,
#   44744,
#   38474,
#   42379,
#   44738,
#   76734,
#   61549,
#   39533,
#   74149,
#   42670,
#   42669,
#   44746,
#   44754,
#   39532,
#   42469,
#   44745,
#   42491,
#   42549,
#   843764,
#   55499,
#   37971,
#   38950,
#   38648,
#   38498,
#   42229,
#   39881,
#   39883,
#   78188,
#   38598,
#   53428,
#   39957,
#   38118,
#   53204,
#   53012,
#   670909,
#   53013,
#   49151,
#   60485,
#   44797,
#   44735,
#   38348,
#   75822,
#   73200,
#   40633,
#   36029,
#   39097,
#   42178,
#   39327,
#   45795,
#   49148,
#   49256,
#   49241,
#   42335,
#   42542,
#   42532,
#   38115,
#   37426,
#   44346,
#   64484,
#   38716,
#   42429,
#   38095,
#   37411,
#   38109,
#   37734,
#   38224,
#   38093,
#   38100,
#   38226,
#   38489,
#   38496,
#   38495,
#   38789,
#   38777,
#   39385,
#   72739,
#   49575,
#   54207,
#   42700,
#   49380,
#   76766,
#   52976,
#   36046,
#   49589,
#   49540,
#   49588,
#   42729,
#   44798,
#   49889,
#   40407,
#   59222,
#   59425,
#   692123,
#   54208,
#   680960,
#   53774,
#   39355,
#   52777,
#   50897,
#   38518,
#   42221,
#   42505,
#   38119,
#   40211,
#   42498,
#   61650,
#   49567,
#   44523,
#   38128,
#   768115,
#   45756,
#   48927,
#   53197,
#   45775,
#   41491,
#   44918,
#   41488,
#   49146,
#   60435,
#   36090,
#   45804,
#   60451,
#   671043,
#   78283,
#   48969,
#   722026,
#   42547,
#   39742,
#   37801,
#   40487,
#   45682,
#   42502,
#   42517,
#   38372,
#   78392,
#   40712,
#   38635,
#   39880,
#   42012,
#   38260,
#   44348,
#   72508,
#   38221,
#   38097,
#   72671,
#   76768,
#   42433,
#   42727,
#   57875,
#   53474,
#   45751,
#   40681,
#   40766,
#   36131,
#   37788,
#   38788,
#   39649,
#   76974,
#   72485,
#   713008,
#   49164,
#   40080,
#   48950,
#   60465,
#   60441,
#   60470,
#   60469,
#   62739,
#   61825,
#   61430,
#   42447,
#   42513,
#   56220,
#   39096,
#   38111,
#   42495,
#   40406,
#   38937,
#   74426,
#   39351,
#   45428,
#   44858,
#   48948,
#   39668,
#   41483,
#   76463,
#   45776,
#   40508,
#   49549,
#   62953,
#   49534,
#   54289,
#   49552,
#   42445,
#   38245,
#   39322,
#   38223,
#   44910,
#   44512,
#   44516,
#   670990,
#   54209,
#   44800,
#   39906,
#   42323,
#   44893,
#   44838,
#   44839,
#   44840,
#   44891,
#   44890,
#   739543,
#   39582,
#   75292,
#   45182,
#   37966,
#   50688,
#   60870,
#   35996,
#   49436,
#   44799,
#   813664,
#   39936,
#   733847,
#   53009,
#   670952,
#   45652,
#   671051,
#   39915,
#   39918,
#   53198,
#   49158,
#   45675,
#   42174,
#   42169,
#   42170,
#   42168,
#   42175,
#   42166,
#   42172,
#   42164,
#   40456,
#   41479,
#   40081,
#   53180,
#   42508,
#   670969,
#   77863,
#   39931,
#   60437,
#   42465,
#   42544,
#   38210,
#   42533,
#   38187,
#   39415,
#   38222,
#   36038,
#   42340,
#   42439,
#   49193,
#   61660,
#   42724,
#   42703,
#   42712,
#   49222,
#   39707,
#   38252,
#   44590,
#   60443,
#   56786,
#   55236,
#   57005,
#   56384,
#   56214,
#   36495,
#   36498,
#   55369,
#   45218,
#   40054,
#   38575,
#   39165,
#   63022,
#   63024,
#   63028,
#   63023,
#   48557,
#   48511,
#   48806,
#   48807,
#   48805,
#   45995,
#   45980,
#   45946,
#   45944,
#   63000,
#   47195,
#   47250,
#   47204,
#   47249,
#   47332,
#   47761,
#   47508,
#   47943,
#   63021,
#   63029,
#   63030,
#   63025,
#   63031,
#   42731,
#   42707,
#   47571,
#   44859,
#   40512,
#   42176,
#   53233,
#   56727,
#   56785,
#   56240,
#   56217,
#   45030,
#   40278,
#   48870,
#   48871,
#   52344,
#   52349,
#   41753,
#   63038,
#   41773,
#   42177,
#   47835,
#   76565,
#   76568,
#   76571,
#   76561,
#   48765,
#   47979,
#   47971,
#   48651,
#   48748,
#   48778,
#   48556,
#   48773,
#   48728,
#   48541,
#   48099,
#   47975,
#   48801,
#   47974,
#   47973,
#   50217,
#   45556,
#   44937,
#   45559,
#   44440,
#   45552,
#   45553,
#   45554,
#   44441,
#   45555,
#   45560,
#   45558,
#   45557,
#   45561,
#   44448,
#   52444,
#   52345,
#   52357,
#   52479,
#   52478,
#   52355,
#   56856,
#   56855,
#   53469,
#   56854,
#   46000,
#   45823,
#   45839,
#   45972,
#   45828,
#   45943,
#   45825,
#   45824,
#   45904,
#   45881,
#   45977,
#   45926,
#   45936,
#   45949,
#   45966,
#   46010,
#   45922,
#   45827,
#   46002,
#   45988,
#   45871,
#   45838,
#   45959,
#   45918,
#   45853,
#   45993,
#   45861,
#   45826,
#   45892,
#   46005,
#   46983,
#   47100,
#   46600,
#   47004,
#   46498,
#   46482,
#   46968,
#   46114,
#   47005,
#   46971,
#   47001,
#   47097,
#   47000,
#   46510,
#   46975,
#   46488,
#   47067,
#   47096,
#   47066,
#   46974,
#   46486,
#   46500,
#   47048,
#   47087,
#   46686,
#   47038,
#   46496,
#   46696,
#   46107,
#   47003,
#   47046,
#   46972,
#   46576,
#   46487,
#   46698,
#   46511,
#   46990,
#   46103,
#   46848,
#   46090,
#   47090,
#   47002,
#   47095,
#   62382,
#   63003,
#   63006,
#   62993,
#   62933,
#   62938,
#   62992,
#   63015,
#   62911,
#   62996,
#   62998,
#   62913,
#   62561,
#   63020,
#   62934,
#   62916,
#   62936,
#   63007,
#   62941,
#   62940,
#   62924,
#   47140,
#   47397,
#   47331,
#   47327,
#   47214,
#   47150,
#   47261,
#   47141,
#   47180,
#   47304,
#   47146,
#   47181,
#   47353,
#   47474,
#   47260,
#   47385,
#   47268,
#   47392,
#   47202,
#   47262,
#   47222,
#   47415,
#   47224,
#   47182,
#   47151,
#   47193,
#   47197,
#   47414,
#   47416,
#   47391,
#   47444,
#   47183,
#   47228,
#   47119,
#   47168,
#   47363,
#   47637,
#   47658,
#   47544,
#   47968,
#   47477,
#   47543,
#   47478,
#   47542,
#   47902,
#   47846,
#   47594,
#   47721,
#   47967,
#   47948,
#   47541,
#   47959,
#   47661,
#   47568,
#   47830,
#   47498,
#   47940,
#   47869,
#   47525,
#   47870,
#   47593,
#   47915,
#   47695,
#   47928,
#   47479,
#   47499,
#   47537,
#   47785,
#   47969,
#   47719,
#   47618,
#   62912,
#   63004,
#   62919,
#   62999,
#   62917,
#   62943,
#   62914,
#   62942,
#   62995,
#   63040,
#   63047,
#   63034,
#   63026,
#   63035,
#   63048,
#   63049,
#   63042,
#   63033,
#   63054,
#   63046,
#   63041,
#   63032,
#   63036,
#   ...]}

# %%
cat_ids = cats['objectIDs']

# %%
cat_ids
# Out:
# [49698,
#  49470,
#  53222,
#  36221,
#  60873,
#  70541,
#  752008,
#  43402,
#  47358,
#  49467,
#  54747,
#  54626,
#  55919,
#  59775,
#  55923,
#  36075,
#  50826,
#  57204,
#  53653,
#  42922,
#  56602,
#  47051,
#  47052,
#  72842,
#  69780,
#  59121,
#  38952,
#  39199,
#  38177,
#  59903,
#  73809,
#  59763,
#  49050,
#  58462,
#  45282,
#  39092,
#  38158,
#  38160,
#  38162,
#  38994,
#  50780,
#  53441,
#  55948,
#  54124,
#  59248,
#  36411,
#  58779,
#  73046,
#  38949,
#  671015,
#  42932,
#  45065,
#  56780,
#  42915,
#  59249,
#  36346,
#  51660,
#  670898,
#  55914,
#  39764,
#  55967,
#  69410,
#  68841,
#  55148,
#  76442,
#  37011,
#  36621,
#  58218,
#  54445,
#  57560,
#  56070,
#  41681,
#  53590,
#  58002,
#  45667,
#  50827,
#  46723,
#  36539,
#  38452,
#  39698,
#  39699,
#  54809,
#  57106,
#  75200,
#  38951,
#  38176,
#  38462,
#  75909,
#  38293,
#  38315,
#  52995,
#  52994,
#  53005,
#  53422,
#  70582,
#  73158,
#  671014,
#  670965,
#  75747,
#  671023,
#  74813,
#  53408,
#  53203,
#  53007,
#  53200,
#  53457,
#  53231,
#  53416,
#  53414,
#  53001,
#  53234,
#  52996,
#  53006,
#  53410,
#  53176,
#  53002,
#  671016,
#  670994,
#  53419,
#  761386,
#  53221,
#  53439,
#  671056,
#  53456,
#  53010,
#  53219,
#  54540,
#  53446,
#  53241,
#  53187,
#  53167,
#  53179,
#  72585,
#  671024,
#  53178,
#  50486,
#  670961,
#  55802,
#  53427,
#  43247,
#  74421,
#  53429,
#  53165,
#  53175,
#  53190,
#  53157,
#  53172,
#  670891,
#  39901,
#  670920,
#  53449,
#  670943,
#  56128,
#  78227,
#  667348,
#  45640,
#  54576,
#  54567,
#  670908,
#  53660,
#  670916,
#  670910,
#  670949,
#  670883,
#  73352,
#  671036,
#  670989,
#  671042,
#  670894,
#  670947,
#  670882,
#  670938,
#  671039,
#  53458,
#  670917,
#  68411,
#  74423,
#  36118,
#  38451,
#  53444,
#  53426,
#  64872,
#  670974,
#  45358,
#  670968,
#  671035,
#  54184,
#  76091,
#  69670,
#  77871,
#  76458,
#  39902,
#  72747,
#  45359,
#  39163,
#  53230,
#  53453,
#  670897,
#  670995,
#  73355,
#  73358,
#  670921,
#  671007,
#  671005,
#  670993,
#  53424,
#  36315,
#  53228,
#  670981,
#  53454,
#  77657,
#  74424,
#  69860,
#  53465,
#  76769,
#  75586,
#  44292,
#  37397,
#  38267,
#  38165,
#  670950,
#  670942,
#  670928,
#  671026,
#  670979,
#  671046,
#  54774,
#  671055,
#  671050,
#  53443,
#  53466,
#  56901,
#  671008,
#  78670,
#  671028,
#  53409,
#  671027,
#  670915,
#  53401,
#  53245,
#  38926,
#  53202,
#  52987,
#  53421,
#  53246,
#  53445,
#  53423,
#  65392,
#  53405,
#  53008,
#  670913,
#  53183,
#  671031,
#  38304,
#  78195,
#  73359,
#  39076,
#  44723,
#  78197,
#  76453,
#  40765,
#  53174,
#  671020,
#  53238,
#  40478,
#  77799,
#  670951,
#  76462,
#  670963,
#  57062,
#  62744,
#  52988,
#  53406,
#  53404,
#  670923,
#  53004,
#  53207,
#  53199,
#  670541,
#  670542,
#  670540,
#  53455,
#  40285,
#  65394,
#  39331,
#  53189,
#  670887,
#  670904,
#  37800,
#  38265,
#  670933,
#  49129,
#  670896,
#  670907,
#  61658,
#  42725,
#  39640,
#  38945,
#  72381,
#  671032,
#  670903,
#  670960,
#  53892,
#  53195,
#  65417,
#  670889,
#  54779,
#  53181,
#  727181,
#  52990,
#  671052,
#  52946,
#  41493,
#  53461,
#  53451,
#  57612,
#  38303,
#  39635,
#  42722,
#  38011,
#  38930,
#  38159,
#  38341,
#  38335,
#  38330,
#  53430,
#  53447,
#  53448,
#  60473,
#  53154,
#  53156,
#  53237,
#  53226,
#  40507,
#  42693,
#  40256,
#  52378,
#  48754,
#  50345,
#  46509,
#  42219,
#  53120,
#  38435,
#  38620,
#  39413,
#  39639,
#  39111,
#  40527,
#  40528,
#  74906,
#  38202,
#  53123,
#  671001,
#  49238,
#  40510,
#  644664,
#  53223,
#  54773,
#  45657,
#  671017,
#  670945,
#  671034,
#  53242,
#  53162,
#  54782,
#  53163,
#  53194,
#  53463,
#  53186,
#  43091,
#  53240,
#  40257,
#  42733,
#  53450,
#  42348,
#  42162,
#  700508,
#  45812,
#  48879,
#  40524,
#  53415,
#  53462,
#  36100,
#  53212,
#  53188,
#  53413,
#  49174,
#  75831,
#  44616,
#  42704,
#  39859,
#  38983,
#  39623,
#  42015,
#  42088,
#  72605,
#  73309,
#  40361,
#  40467,
#  40468,
#  42585,
#  854924,
#  40741,
#  40604,
#  40605,
#  40612,
#  40611,
#  40610,
#  40606,
#  40607,
#  40674,
#  40608,
#  40613,
#  40614,
#  40609,
#  40603,
#  36451,
#  38228,
#  74448,
#  39166,
#  38328,
#  856419,
#  670970,
#  45763,
#  39482,
#  53460,
#  53158,
#  52096,
#  78198,
#  39524,
#  49216,
#  50898,
#  76733,
#  39527,
#  42463,
#  39528,
#  42378,
#  38108,
#  44744,
#  38474,
#  42379,
#  44738,
#  76734,
#  61549,
#  39533,
#  74149,
#  42670,
#  42669,
#  44746,
#  44754,
#  39532,
#  42469,
#  44745,
#  42491,
#  42549,
#  843764,
#  55499,
#  37971,
#  38950,
#  38648,
#  38498,
#  42229,
#  39881,
#  39883,
#  78188,
#  38598,
#  53428,
#  39957,
#  38118,
#  53204,
#  53012,
#  670909,
#  53013,
#  49151,
#  60485,
#  44797,
#  44735,
#  38348,
#  75822,
#  73200,
#  40633,
#  36029,
#  39097,
#  42178,
#  39327,
#  45795,
#  49148,
#  49256,
#  49241,
#  42335,
#  42542,
#  42532,
#  38115,
#  37426,
#  44346,
#  64484,
#  38716,
#  42429,
#  38095,
#  37411,
#  38109,
#  37734,
#  38224,
#  38093,
#  38100,
#  38226,
#  38489,
#  38496,
#  38495,
#  38789,
#  38777,
#  39385,
#  72739,
#  49575,
#  54207,
#  42700,
#  49380,
#  76766,
#  52976,
#  36046,
#  49589,
#  49540,
#  49588,
#  42729,
#  44798,
#  49889,
#  40407,
#  59222,
#  59425,
#  692123,
#  54208,
#  680960,
#  53774,
#  39355,
#  52777,
#  50897,
#  38518,
#  42221,
#  42505,
#  38119,
#  40211,
#  42498,
#  61650,
#  49567,
#  44523,
#  38128,
#  768115,
#  45756,
#  48927,
#  53197,
#  45775,
#  41491,
#  44918,
#  41488,
#  49146,
#  60435,
#  36090,
#  45804,
#  60451,
#  671043,
#  78283,
#  48969,
#  722026,
#  42547,
#  39742,
#  37801,
#  40487,
#  45682,
#  42502,
#  42517,
#  38372,
#  78392,
#  40712,
#  38635,
#  39880,
#  42012,
#  38260,
#  44348,
#  72508,
#  38221,
#  38097,
#  72671,
#  76768,
#  42433,
#  42727,
#  57875,
#  53474,
#  45751,
#  40681,
#  40766,
#  36131,
#  37788,
#  38788,
#  39649,
#  76974,
#  72485,
#  713008,
#  49164,
#  40080,
#  48950,
#  60465,
#  60441,
#  60470,
#  60469,
#  62739,
#  61825,
#  61430,
#  42447,
#  42513,
#  56220,
#  39096,
#  38111,
#  42495,
#  40406,
#  38937,
#  74426,
#  39351,
#  45428,
#  44858,
#  48948,
#  39668,
#  41483,
#  76463,
#  45776,
#  40508,
#  49549,
#  62953,
#  49534,
#  54289,
#  49552,
#  42445,
#  38245,
#  39322,
#  38223,
#  44910,
#  44512,
#  44516,
#  670990,
#  54209,
#  44800,
#  39906,
#  42323,
#  44893,
#  44838,
#  44839,
#  44840,
#  44891,
#  44890,
#  739543,
#  39582,
#  75292,
#  45182,
#  37966,
#  50688,
#  60870,
#  35996,
#  49436,
#  44799,
#  813664,
#  39936,
#  733847,
#  53009,
#  670952,
#  45652,
#  671051,
#  39915,
#  39918,
#  53198,
#  49158,
#  45675,
#  42174,
#  42169,
#  42170,
#  42168,
#  42175,
#  42166,
#  42172,
#  42164,
#  40456,
#  41479,
#  40081,
#  53180,
#  42508,
#  670969,
#  77863,
#  39931,
#  60437,
#  42465,
#  42544,
#  38210,
#  42533,
#  38187,
#  39415,
#  38222,
#  36038,
#  42340,
#  42439,
#  49193,
#  61660,
#  42724,
#  42703,
#  42712,
#  49222,
#  39707,
#  38252,
#  44590,
#  60443,
#  56786,
#  55236,
#  57005,
#  56384,
#  56214,
#  36495,
#  36498,
#  55369,
#  45218,
#  40054,
#  38575,
#  39165,
#  63022,
#  63024,
#  63028,
#  63023,
#  48557,
#  48511,
#  48806,
#  48807,
#  48805,
#  45995,
#  45980,
#  45946,
#  45944,
#  63000,
#  47195,
#  47250,
#  47204,
#  47249,
#  47332,
#  47761,
#  47508,
#  47943,
#  63021,
#  63029,
#  63030,
#  63025,
#  63031,
#  42731,
#  42707,
#  47571,
#  44859,
#  40512,
#  42176,
#  53233,
#  56727,
#  56785,
#  56240,
#  56217,
#  45030,
#  40278,
#  48870,
#  48871,
#  52344,
#  52349,
#  41753,
#  63038,
#  41773,
#  42177,
#  47835,
#  76565,
#  76568,
#  76571,
#  76561,
#  48765,
#  47979,
#  47971,
#  48651,
#  48748,
#  48778,
#  48556,
#  48773,
#  48728,
#  48541,
#  48099,
#  47975,
#  48801,
#  47974,
#  47973,
#  50217,
#  45556,
#  44937,
#  45559,
#  44440,
#  45552,
#  45553,
#  45554,
#  44441,
#  45555,
#  45560,
#  45558,
#  45557,
#  45561,
#  44448,
#  52444,
#  52345,
#  52357,
#  52479,
#  52478,
#  52355,
#  56856,
#  56855,
#  53469,
#  56854,
#  46000,
#  45823,
#  45839,
#  45972,
#  45828,
#  45943,
#  45825,
#  45824,
#  45904,
#  45881,
#  45977,
#  45926,
#  45936,
#  45949,
#  45966,
#  46010,
#  45922,
#  45827,
#  46002,
#  45988,
#  45871,
#  45838,
#  45959,
#  45918,
#  45853,
#  45993,
#  45861,
#  45826,
#  45892,
#  46005,
#  46983,
#  47100,
#  46600,
#  47004,
#  46498,
#  46482,
#  46968,
#  46114,
#  47005,
#  46971,
#  47001,
#  47097,
#  47000,
#  46510,
#  46975,
#  46488,
#  47067,
#  47096,
#  47066,
#  46974,
#  46486,
#  46500,
#  47048,
#  47087,
#  46686,
#  47038,
#  46496,
#  46696,
#  46107,
#  47003,
#  47046,
#  46972,
#  46576,
#  46487,
#  46698,
#  46511,
#  46990,
#  46103,
#  46848,
#  46090,
#  47090,
#  47002,
#  47095,
#  62382,
#  63003,
#  63006,
#  62993,
#  62933,
#  62938,
#  62992,
#  63015,
#  62911,
#  62996,
#  62998,
#  62913,
#  62561,
#  63020,
#  62934,
#  62916,
#  62936,
#  63007,
#  62941,
#  62940,
#  62924,
#  47140,
#  47397,
#  47331,
#  47327,
#  47214,
#  47150,
#  47261,
#  47141,
#  47180,
#  47304,
#  47146,
#  47181,
#  47353,
#  47474,
#  47260,
#  47385,
#  47268,
#  47392,
#  47202,
#  47262,
#  47222,
#  47415,
#  47224,
#  47182,
#  47151,
#  47193,
#  47197,
#  47414,
#  47416,
#  47391,
#  47444,
#  47183,
#  47228,
#  47119,
#  47168,
#  47363,
#  47637,
#  47658,
#  47544,
#  47968,
#  47477,
#  47543,
#  47478,
#  47542,
#  47902,
#  47846,
#  47594,
#  47721,
#  47967,
#  47948,
#  47541,
#  47959,
#  47661,
#  47568,
#  47830,
#  47498,
#  47940,
#  47869,
#  47525,
#  47870,
#  47593,
#  47915,
#  47695,
#  47928,
#  47479,
#  47499,
#  47537,
#  47785,
#  47969,
#  47719,
#  47618,
#  62912,
#  63004,
#  62919,
#  62999,
#  62917,
#  62943,
#  62914,
#  62942,
#  62995,
#  63040,
#  63047,
#  63034,
#  63026,
#  63035,
#  63048,
#  63049,
#  63042,
#  63033,
#  63054,
#  63046,
#  63041,
#  63032,
#  63036,
#  ...]

# %%
dff = []

# %%
i = 0
for i in cat_ids[:1000]:
    try:
        r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{i}')
        obj_test = r_test.json()
        dff.append([obj_test['objectID'], obj_test['title'], obj_test['artistDisplayName'], obj_test['department'], obj_test['objectBeginDate'], obj_test['objectEndDate'], obj_test['period'], obj_test['objectName'], obj_test['culture']])
    except:
        continue
dff_1 = pd.DataFrame(dff)
dff_2 = dff_1.rename(columns = {0: 'objectID', 1: 'title', 2: 'artistDisplayName', 3: 'department', 4: 'objectBeginDate', 5: 'objectEndDate', 6: 'period', 7: 'objectName', 8: 'culture'})

# %%
dff_2
# Out:
#      objectID                                              title  \
# 0       49698                                                Cat
# 1       49470                                                Cat
# 2       53222                                           Musk Cat
# 3       36221                                                Cat
# 4       60873                                       Burial Crown
# ..        ...                                                ...
# 995     63054                    Jar with Scrolling Peony Design
# 996     63046                                           Wine pot
# 997     63041  Small Dish with Cherry Blossoms in Bamboo Baskets
# 998     63032                  Square Stand with Dutch Landscape
# 999     63036                                     Box for Sweets
#
#     artistDisplayName department  objectBeginDate  objectEndDate  \
# 0       Zhang Yuguang  Asian Art             1900           1968
# 1             Wang Li  Asian Art             1813           1879
# 2          Uto Gyoshi  Asian Art             1550           1599
# 3            Wang Yun  Asian Art             1900           1933
# 4                      Asian Art              960           1279
# ..                ...        ...              ...            ...
# 995                    Asian Art             1870           1870
# 996                    Asian Art             1820           1820
# 997                    Asian Art             1690           1720
# 998                    Asian Art             1750           1833
# 999                    Asian Art             1710           1730
#
#                                period                            objectName  \
# 0                                      Folding fan mounted as an album leaf
# 1            Qing dynasty (1644–1911)                        Hanging scroll
# 2        Muromachi period (1392–1573)                        Hanging scroll
# 3                                                            Hanging scroll
# 4    Song dynasty (960–1279) or later                          Burial crown
# ..                                ...                                   ...
# 995          Meiji period (1868–1912)                                   Jar
# 996            Edo period (1615–1868)                              Wine pot
# 997            Edo period (1615–1868)                                  Dish
# 998            Edo period (1615–1868)                                 Stand
# 999            Edo period (1615–1868)                        Box for sweets
#
#     culture
# 0     China
# 1     China
# 2     Japan
# 3     China
# 4     China
# ..      ...
# 995   Japan
# 996   Japan
# 997   Japan
# 998   Japan
# 999   Japan
#
# [1000 rows x 9 columns]

# %%
dff_2.value_counts('period')
# Out:
# period
# Edo period (1615–1868)                           442
#                                                   99
# Qing dynasty (1644–1911)                          58
# Ming dynasty (1368–1644)                          41
# Muromachi period (1392–1573)                      30
#                                                 ...
# Kofun period (ca. 3rd–7th century)                 1
# Kofun period (ca. 300–710)                         1
# Khmer Empire (802–1431)                            1
# Kandyan period                                     1
# Sui (581–618) or early Tang (618-907) dynasty      1
# Length: 109, dtype: int64
